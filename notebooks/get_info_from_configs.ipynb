# %%
import sys
sys.path.append('..')

from root import ROOT
from data.fwf_dataset import FwfDataset

from omegaconf import OmegaConf
import os
import json
import numpy as np
import pandas as pd
from glob import glob

# %%
config_dir = f'{ROOT}/config/batch_05'

for cfg_fp in glob(os.path.join(config_dir, '*.yaml')):
    cfg = OmegaConf.load(cfg_fp)
    print(cfg.experiment.title_suffix, cfg.experiment.description, )
# Out:
# v500 baseline.
# v501 Color +-
# v502 Riegl +-
# v503 Waveform +-
# v504 Are Waveform and riegl correlated (handle the same information?)
# v505 Is scan position information relevant for waveform?  (compare with v004)
# v506 Is geometric information relevant (compare with v003 )
# v507 Are neibors needed? (compare with v006)
# v508 Is geometric information relevant (compare with v003)
